# %%
import pandas as pd
import yaml
from tqdm import tqdm
import numpy as np

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('events_statist_v2.csv')

# %%
df['Надо_переносить'].fillna('no_comment', inplace=True)

# %%
stat = df[['Event', 'Надо_переносить']].groupby('Надо_переносить').nunique()

# %%
stat['share'] = stat['Event'] / stat['Event'].sum()

# %%
stat
# Out:
#                  Event     share
# Надо_переносить
# no_comment        1112  0.638347
# Да                 126  0.072331
# Нет                 11  0.006315
# д                    1  0.000574
# да                 263  0.150976
# нет                229  0.131458

# %%
df_properties = pd.read_csv('sme_mb_90_day_schema_2.csv')

# %%
df_properties.columns = [c.replace(' ', '_').lower() for c in df_properties.columns]

# %%
parsed_data = pd.DataFrame(columns=['event_name', 'event_desc', 'num_props', 'prop_name', 'prop_desc'])

for row in df_properties.itertuples():

    try:
        np.isnan(row.event)
    except TypeError:
        event_name = row.event
        event_desc = row.event_description
        num_props = row.event_number_of_properties
        
    parsed_data = parsed_data.append({
        'event_name':event_name, 'event_desc':event_desc,
        'num_props':num_props, 'prop_name':row.event_property,
        'prop_desc':row.property_description},
        ignore_index=True)
# Out:
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# ...
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({
# /var/folders/w5/rpr1j8nx0tnb8w7bgcg6pfm00000gq/T/ipykernel_13486/1238761445.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parsed_data = parsed_data.append({

# %%
data = df[df['Надо_переносить'].isin(['да', 'Да', 'д'])]
data = data[['Event','Event_Description','Event_Number_of_Properties']]
data = data.merge(parsed_data, left_on='Event', right_on='event_name', how='left')

# %%
data = data[['Event','Event_Description','Event_Number_of_Properties','prop_name','prop_desc']]

data.columns = ['event', 'event_disc', 'params_qty', 'param', 'param_disc']

# %%
data.event_disc = data.event_disc.fillna('Необходимо добавить описание события')
data.param_disc = data.param_disc.fillna('Необходимо добавить описание параметра')

# %%
data
# Out:
#                                         event  \
# 0            Origination_Access_Account_Shown
# 1                  Origination_Added_Employee
# 2                  Origination_Added_Employee
# 3            Origination_Added_Employee_Error
# 4                    Origination_Already_User
# ..                                        ...
# 609                 Tariffs_Change_Down_Shown
# 610                   Tariffs_Change_Up_Shown
# 611                  Tariffs_Comparison_Shown
# 612                  Tariffs_Comparison_Shown
# 613  TinkoffAccounting_InstallOnbording_Close
#
#                                             event_disc  params_qty  \
# 0                   При показе экрана "Доступ к счету"           1
# 1    При успешном добавлении сотрудника. Передаем в...           2
# 2    При успешном добавлении сотрудника. Передаем в...           2
# 3    При выскакивании попапа "Выберете хотя бы один...           1
# 4                  При показе экрана "Проверьте номер"           0
# ..                                                 ...         ...
# 609               Необходимо добавить описание события           0
# 610               Необходимо добавить описание события           0
# 611               Необходимо добавить описание события           2
# 612               Необходимо добавить описание события           2
# 613               Необходимо добавить описание события           0
#
#                  param                              param_disc
# 0                   id  Необходимо добавить описание параметра
# 1           accessType  Необходимо добавить описание параметра
# 2                   id  Необходимо добавить описание параметра
# 3                   id  Необходимо добавить описание параметра
# 4                  NaN  Необходимо добавить описание параметра
# ..                 ...                                     ...
# 609                NaN  Необходимо добавить описание параметра
# 610                NaN  Необходимо добавить описание параметра
# 611  tariffCodeCompare  Необходимо добавить описание параметра
# 612  tariffCodeCurrent  Необходимо добавить описание параметра
# 613                NaN  Необходимо добавить описание параметра
#
# [614 rows x 5 columns]

# %%
for event in tqdm(data.event.unique()):
    #print(event)
    
    iter_event_df = data[data['event']==event]

    e_disc = iter_event_df.event_disc[:1].squeeze()

    params_dict = {}

    if iter_event_df.params_qty[:1].squeeze() > 0:
        for p in iter_event_df.param.unique():
            p_disc = iter_event_df[iter_event_df['param']==p]['param_disc'].squeeze()

            params_dict.update({p: {'meta': {'description': p_disc},
                                    'alias': p, 'type': 'String', 'nullable': False}})

    event_file = {
        'meta': {'description': e_disc,
                 'maintainers': [],
                 'tasks': [],
                 'labels': ['sme_transfer_script']},
        'alias': {'system': 'amplitude',
                  'name': event},
        'parameters': params_dict,
        'settings': {},
        'clickhouse': {
            'enabled': True}

    }

    with open(f'sme_amplitude_events_2/{event}.yml', 'w') as file:
        try:
            yaml.dump(event_file, file, allow_unicode=True)
        except yaml.YAMLError as exc:
            print(exc)
# Out:
# 100%|████████████████████████████████████████| 390/390 [00:01<00:00, 368.56it/s]
